# %% [markdown]
# # PYTHON ASSIGNMENT - FINAL PROJECT
# # RBA GROUP 09

# %% [markdown]
# #### 09-Aswin Dath A M
# #### 58-Vaishnavi Jha
# #### 18-Prasad Fulpagar
# #### 37-Ankita Rai
# #### 03-Aditya Singh
# #### 52-Suraj Kumar`

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Reading CSV

# %%
df =pd.read_csv("hotel_bookings.csv")

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.shape #To find the number of rows and columns
# Out:
# (119390, 32)

# %%
df.head() #To analyse the first few rows of the data
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail() #To analyse the last few rows of the data
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.columns # To analyse the coulumns of the data
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info() # To analyse the datatypes of the
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Changing datatype of [reservation_status_date] from object to datetime
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], dayfirst=True)

# %%
df.info() # Recheck
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# To Identify the number of unique features in the data
df.describe(include="object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# Analysing Column wise unique values.
for col in df.describe(include="object").columns:
  print(col)
  print(df[col].unique())
  print("-"*80)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %% [markdown]
# ## Data Cleaning & Preprocessing

# %% [markdown]
# #### Removing Null Values

# %%
df.isnull().sum() # To analyse the number of null values
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ##### [country] : In a dataset with 119390 rows dropping 488 rows wont make much difference rather increase the accuracy of the analysis
# ##### [agent]   : Its better to drop agent rater than handling 16340 null values, because agent is not relevent to the study
# ##### [company] : Its better to drop company rater than handling 112593 null values, which is closer to the number of actual data

# %%
df.drop(['company','agent'],axis=1,inplace=True) # droping country and agent
df.dropna(inplace=True) # Removing rows with null values

# %%
df.isnull().sum() # Recheck
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# #### Removing Outliers

# %%
df.describe() # To analyze the Summary Statistics
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# ##### From the summary statistics we can see that adr is the only column with an outlier which is relevent to this study so we will only handle the outlier in adr

# %%
# vistualizing adr to analyze outliers
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
df=df[df['adr']<5000] #removing outliers

# %%
df.describe() #recheck
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# ##### Outliers are removed

# %% [markdown]
# ## Data Analysis and Visualization

# %%
cancelled_perc=df['is_canceled'].value_counts(normalize=True) #To analyze cancelletion rates

# %%
print("not cancelled",cancelled_perc[0]*100,"%")
print("cancelled    ",cancelled_perc[1]*100,"%")
# Out:
# not cancelled 62.865337224656635 %
# cancelled     37.134662775343365 %

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# ##### To analyse the reservation Status Count.

# %%
plt.figure(figsize=(5,5))
plt.title("reservation Status count")
plt.bar(['Not cancelled','cancelled'],df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
plt.show()

# %% [markdown]
# ##### From the above bar chart and  we can see that 37.1% cancellation is a not good for the hotel

# %% [markdown]
# #

# %% [markdown]
# ### Count Plot

# %% [markdown]
# ##### To find the cancellation ratios in city hotels and resort hotels.

# %%
plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation status in different hotels', size=20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
# Out:
# Text(0, 0.5, 'number of reservations')

# %%
# city_hotel cancellation ratio analysis
city_hotel=df[df['hotel']== 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %%
# resort_hotel cancellation ratio analysis
resort_hotel=df[df['hotel']== 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %% [markdown]
# ##### From the above Count plot and analysis we can see that the proportion of cancellation is more in city hotels

# %% [markdown]
# #

# %% [markdown]
# ### ADR Plot- City Hotel Vs Resort Hotel

# %% [markdown]
# ##### To find the price fluctuation relationship between City and Resort Hotels.

# %%
# Grouping by date
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20, 8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize=30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Here we can find that Resort hotel prices fluctuate more than City Hotels, which has a lower fluctuation.
# ##### 2. Both prices fluctuate but Resort Hotel prices go up much more than city hotels from June to September.
# ##### 3. An Increase in price can be seen in resort hotels during January most probably due to New Year.
# ##### 4. The spikes we see in the above diagram states the prices of are high.

# %% [markdown]
# #

# %% [markdown]
# ### Clustered bar chart

# %% [markdown]
# ##### To analyze reservations and cancellations per month.

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], dayfirst=True)
df['month'] = df['reservation_status_date'].dt.month

# %%
plt.figure(figsize=(16, 8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation status per month', size=20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %% [markdown]
# ##### 1. Here we can find that most cancellations happened in january.
# ##### 2. Cancellations werew low from June to September.
# ##### 3. Cancellations were the lowest on August as well as Highest non cancellation rates.

# %% [markdown]
# #

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# ##### to see whether the reservation cancelation and depends upon the price for that month

# %%
plt.figure(figsize=(15, 8))
plt.title('ADR per month', fontsize=30)
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Here we can see that prices are low in august and cancellation is low
# ##### 2. Prices are high in january and cancellations are the highest
# ##### 3. This supports the statement that when price increases cancellatioin also increases

# %% [markdown]
# #

# %% [markdown]
# ### Multi line Chart

# %% [markdown]
# #### Daily Average Rate vs Cancelled and Non Cancelled bookings

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], dayfirst=True)
cancelled_data = df[df['is_canceled'] == 1]
not_cancelled_data = df[df['is_canceled'] == 0]

cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# %%
cancelled_df_adr=cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016') & ( cancelled_df_adr['reservation_status_date']<'2017-09')]
not_cancelled_df_adr=not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016') & (not_cancelled_df_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate', fontsize=30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Here we can see that The average daily rate for cancelled is more than not cancelled except seasonal times(June, July)
# ##### 2. Which means that our hypothesis is right and high price is a factor for high cancellation rates

# %% [markdown]
# #

# %% [markdown]
# ### Pie Chart

# %% [markdown]
# #### Top 10 countries whith high cancellation rates

# %%
cancelled_data = df[df['is_canceled'] == 1]  # Correct the condition
top_10_country = cancelled_data['country'].value_counts()[:10]

# %% [markdown]
# #### Portugal has the most number of cancellatioins amounting to 70.7% which is really concerning

# %%
plt.figure(figsize=(8,8))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country, autopct='%1.2f%%', labels=top_10_country.index) # Corrected autopct format
plt.show()

# %% [markdown]
# ### Bar Charts

# %% [markdown]
# #### 1.To find the majority in market segments

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='market_segment', order=df['market_segment'].value_counts().index,
              palette='viridis')
plt.xlabel("market_segment")
plt.ylabel("Number of Bookings")
plt.title("Number of Bookings by market segment ")
plt.xticks(rotation=45)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True) * 100
# Out:
# market_segment
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: proportion, dtype: float64

# %% [markdown]
# ##### 1.  47% of clients book through online travel agencies
# ##### 2. 16% make reservations as part of a group.
# ##### 3. 10% of clients book directly by visiting the hotels in person

# %% [markdown]
# #

# %% [markdown]
# #### 1.To find the majority in Distribution Channels

# %%
# Calculate the number of bookings per distribution channel
channel_counts = df['distribution_channel'].value_counts()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=channel_counts.index, y=channel_counts.values, palette='magma')
plt.xlabel("Distribution Channel")
plt.ylabel("Number of Bookings")
plt.title("Distribution Channel Performance - Number of Bookings")
plt.xticks(rotation=45)
for index, value in enumerate(channel_counts.values):
    plt.text(index, value + 500, str(value), ha='center')
plt.show()

# %% [markdown]
# #### 1. The distribution channel performance chart shows that most bookings come through a dominant channel, likely Travel Agents/Tour Operators (TA/TO), highlighting their strong role in hotel reservations.
# #### 2. Direct bookings appear lower, suggesting that customers prefer third-party platforms for convenience or better deals. Some channels have minimal bookings, indicating a lower contribution to overall reservations

# %% [markdown]
# #

# %% [markdown]
# #### 3.To see if online market is very high in cancelation also

# %%
cancelled_data['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        20738
# Groups           12097
# Offline TA/TO     8277
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=cancelled_data, x='market_segment', order=cancelled_data['market_segment'].value_counts().index,
              palette='viridis')
plt.xlabel("market_segment")
plt.ylabel("Number of Bookings")
plt.title("Number of Bookings by market segment ")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Here we can see that Online market is also high in cancellation also

# %% [markdown]
# #

# %% [markdown]
# ### Correlation Heatmap

# %% [markdown]
# #### To find if there is a positive relation between waiting period and cancellation

# %%
# Compute correlation matrix for relevant numerical columns
correlation_matrix = df[['days_in_waiting_list', 'is_canceled', 'lead_time', 'adr']].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")
plt.title("Correlation Heatmap of Key Variables")
plt.show()

# %% [markdown]
# ##### 1.The correlation is very weak (close to 0), meaning there is no strong direct relationship between waiting list days and cancellations.
# ##### 2.This suggests that while longer waiting lists might contribute to cancellations, other factors likely have a stronger influence.
